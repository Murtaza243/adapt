# %% [markdown]
# # Model evaluation and re-training with AdaPT on Cifar10 dataset
#
# In this notebook you can evaluate different approximate multipliers on various models based on Cifar10 dataset
#
# Steps:
# * Select models to load
# * Select number of threads to use
# * Choose approximate multiplier
# * Load model for evaluation
# * Load dataset
# * Run model calibration for quantization
# * Run model evaluation
# * Run approximate-aware re-training
# * Rerun model evaluation
#
# **Note**:
# * This notebook should be run on a X86 machine
#
# * Please make sure you have run the installation steps first

# %%
import os
import zipfile
import torch

import requests
from torch.utils.data import DataLoader
from torchvision import transforms as T
from torchvision.datasets import CIFAR10
from tqdm import tqdm
import torch.nn as nn

# %% [markdown]
# ## Select models to load
#
# The weights must be downloaded in state_dicts folder.

# %%
from models.resnet import resnet18, resnet34, resnet50
from models.vgg import vgg11_bn, vgg13_bn, vgg19_bn
from models.densenet import densenet121, densenet161, densenet169
from models.inception import inception_v3 # slow, propably bad cifar10 implementation of inception for PT

# %% [markdown]
# ## Select number of threads to use
#
# For optimal performance set them as the number of your cpu threads (not cpu cores)

# %%
threads = 40
torch.set_num_threads(threads)

#maybe better performance
# %env OMP_PLACES=cores
# %env OMP_PROC_BIND=close
# %env OMP_WAIT_POLICY=active
# Out:
# env: OMP_PLACES=cores
# env: OMP_PROC_BIND=close
# env: OMP_WAIT_POLICY=active

# %% [markdown]
# ## Choose approximate multiplier
#
# Two approximate multipliers are already provided
#
# **mul8s_acc** - (header file: mul8s_acc.h)   <--  default
#
# **mul8s_1L2H** - (header file: mul8s_1L2H.h)
#
#
#
# In order to use your custom multiplier you need to use the provided tool (LUT_generator) to easily create the C++ header for your multiplier. Then you just place it inside the adapt/cpu-kernels/axx_mults folder. The name of the axx_mult here must match the name of the header file. The same axx_mult is used in all layers.
#
# Tip: If you want explicitly to set for each layer a different axx_mult you must do it from the model definition using the respective AdaPT_Conv2d class of each layer.

# %%
axx_mult = 'mul8s_acc'

# %% [markdown]
# ## Load model for evaluation
#
# Jit compilation method loads 'on the fly' the C++ extentions of the approximate multipliers. Then the pytorch model is loaded

# %%
model = resnet50(pretrained=True, axx_mult = axx_mult)

model.eval() # for evaluation
# Out:
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/PyInit_conv2d_mul8s_acc...
# Emitting ninja build file /root/.cache/torch_extensions/PyInit_conv2d_mul8s_acc/build.ninja...
# Building extension module PyInit_conv2d_mul8s_acc...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF axx_conv2d.o.d -DTORCH_EXTENSION_NAME=PyInit_conv2d_mul8s_acc -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.8/dist-packages/torch/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.8/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.8/dist-packages/torch/include/THC -isystem /usr/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -DAXX_MULT=mul8s_acc -march=native -fopenmp -O3 -c /workspace/adapt/adapt/cpu-kernels/axx_conv2d.cpp -o axx_conv2d.o
# [2/2] c++ axx_conv2d.o -shared -lgomp -L/usr/local/lib/python3.8/dist-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o PyInit_conv2d_mul8s_acc.so
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# Using /root/.cache/torch_extensions as PyTorch extensions root...
# No modifications detected for re-loaded extension module PyInit_conv2d_mul8s_acc, skipping build step...
# Loading extension module PyInit_conv2d_mul8s_acc...
# ResNet(
#   (conv1): AdaPT_Conv2d(
#     3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#     (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#     (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#   )
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AdaPT_Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#           (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         )
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AdaPT_Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#           (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         )
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AdaPT_Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#           (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         )
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AdaPT_Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#           (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         )
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): AdaPT_Conv2d(
#         2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): AdaPT_Conv2d(
#         512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): AdaPT_Conv2d(
#         512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (quantizer): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#         (quantizer_w): TensorQuantizer(8bit per-tensor amax=dynamic calibrator=HistogramCalibrator quant)
#       )
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# ## Load dataset

# %%
def val_dataloader(mean = (0.4914, 0.4822, 0.4465), std = (0.2471, 0.2435, 0.2616)):

    transform = T.Compose(
        [
            T.ToTensor(),
            T.Normalize(mean, std),
        ]
    )
    dataset = CIFAR10(root="datasets/cifar10_data", train=False, download=True, transform=transform)
    dataloader = DataLoader(
        dataset,
        batch_size=128,
        num_workers=0,
        drop_last=True,
        pin_memory=False,
    )
    return dataloader

transform = T.Compose(
        [
            T.RandomCrop(32, padding=4),
            T.RandomHorizontalFlip(),
            T.ToTensor(),
            T.Normalize(mean = (0.4914, 0.4822, 0.4465), std = (0.2471, 0.2435, 0.2616)),
        ]
    )
dataset = CIFAR10(root="datasets/cifar10_data", train=True, download=True, transform=transform)

evens = list(range(0, len(dataset), 10))
trainset_1 = torch.utils.data.Subset(dataset, evens)

data = val_dataloader()

# data_t is used for calibration purposes and is a subset of train-set
data_t = DataLoader(trainset_1, batch_size=128,
                                            shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Run model calibration for quantization
#
# Calibrates the quantization parameters
#
# Need to re-run it each time the model changes

# %%
from pytorch_quantization import nn as quant_nn
from pytorch_quantization import calib

def collect_stats(model, data_loader, num_batches):
     """Feed data to the network and collect statistic"""

     # Enable calibrators
     for name, module in model.named_modules():
         if isinstance(module, quant_nn.TensorQuantizer):
             if module._calibrator is not None:
                 module.disable_quant()
                 module.enable_calib()
             else:
                 module.disable()

     for i, (image, _) in tqdm(enumerate(data_loader), total=num_batches):
         model(image.cpu())
         if i >= num_batches:
             break

     # Disable calibrators
     for name, module in model.named_modules():
         if isinstance(module, quant_nn.TensorQuantizer):
             if module._calibrator is not None:
                 module.enable_quant()
                 module.disable_calib()
             else:
                 module.enable()

def compute_amax(model, **kwargs):
 # Load calib result
 for name, module in model.named_modules():
     if isinstance(module, quant_nn.TensorQuantizer):
         if module._calibrator is not None:
             if isinstance(module._calibrator, calib.MaxCalibrator):
                 module.load_calib_amax()
             else:
                 module.load_calib_amax(**kwargs)
         print(F"{name:40}: {module}")
 model.cpu()

# It is a bit slow since we collect histograms on CPU
with torch.no_grad():
    stats = collect_stats(model, data_t, num_batches=2)
    amax = compute_amax(model, method="percentile", percentile=99.99)
    
    # optional - test different calibration methods
    #amax = compute_amax(model, method="mse")
    #amax = compute_amax(model, method="entropy")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:15<00:00,  7.79s/it]
# WARNING: Logging before flag parsing goes to stderr.
# W0604 19:02:39.700676 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.700921 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701092 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701257 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701421 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701586 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701753 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.701912 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.702135 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.702348 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.702548 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.702728 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.702903 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703064 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703234 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703403 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703581 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703757 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.703945 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.704106 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.704264 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.704431 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.704642 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.704854 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705049 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705231 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705389 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705579 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705776 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.705958 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706129 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706305 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706455 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706603 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706756 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.706903 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707047 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707188 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707329 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707473 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707624 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707767 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.707917 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708067 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708214 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708352 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708498 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708650 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708796 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.708943 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709076 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709196 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709322 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709439 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709577 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709735 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.709904 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710081 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710249 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710396 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710577 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710737 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.710893 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711049 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711219 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711376 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711533 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711684 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.711872 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712058 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712248 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712418 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712625 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712821 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.712999 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713145 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713308 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713473 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713666 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713822 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.713983 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714133 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714304 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714468 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714637 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714771 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.714947 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.717803 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718010 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718198 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718369 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718550 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718779 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.718965 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.719159 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.719336 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.719511 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.719669 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.719837 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720012 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720205 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720389 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720570 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720723 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.720886 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.721063 136590162851648 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0604 19:02:39.722014 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.722207 136590162851648 tensor_quantizer.py:238] Call .cuda() if running on GPU after loading calibrated amax.
# W0604 19:02:39.722810 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.723134 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.723594 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.723915 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.724341 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.724636 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.724921 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.725236 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.725739 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.725996 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.726383 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.726635 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.727022 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.727271 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.727616 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.727903 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.728154 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.728418 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.728635 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.728826 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.728999 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.729172 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.729331 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.729506 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.729963 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.730198 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.730400 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.730590 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.730757 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.730941 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.731304 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.731523 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.731734 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.731942 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.732156 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.732320 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.732495 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.732774 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.732941 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.733185 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.733352 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.733611 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.733818 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734023 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734228 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734444 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734645 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734825 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.734993 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.735307 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.735475 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.735733 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.735904 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.736155 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.736373 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.736552 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.736805 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.737082 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.737326 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.737651 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.737884 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.738126 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.738358 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.738759 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.738990 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.739229 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.739567 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.739818 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.740046 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.740282 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.740454 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.740721 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.740950 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.741175 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.741347 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.741534 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.741856 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.742106 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.742302 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.742492 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.742705 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.742904 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.743146 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.743339 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.743774 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.744009 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.744230 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.744458 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.744688 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.744864 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.745386 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.745681 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.745885 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746097 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746299 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746471 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746650 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746818 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.746986 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.747151 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.747322 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.747480 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.747758 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.748025 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0604 19:02:39.748289 136590162851648 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# conv1.quantizer                         : TensorQuantizer(8bit per-tensor amax=2.1255 calibrator=HistogramCalibrator quant)
# conv1.quantizer_w                       : TensorQuantizer(8bit per-tensor amax=0.1625 calibrator=HistogramCalibrator quant)
# layer1.0.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.6309 calibrator=HistogramCalibrator quant)
# layer1.0.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0804 calibrator=HistogramCalibrator quant)
# layer1.0.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2137 calibrator=HistogramCalibrator quant)
# layer1.0.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0355 calibrator=HistogramCalibrator quant)
# layer1.0.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2434 calibrator=HistogramCalibrator quant)
# layer1.0.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0544 calibrator=HistogramCalibrator quant)
# layer1.0.downsample.0.quantizer         : TensorQuantizer(8bit per-tensor amax=0.6309 calibrator=HistogramCalibrator quant)
# layer1.0.downsample.0.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0867 calibrator=HistogramCalibrator quant)
# layer1.1.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2273 calibrator=HistogramCalibrator quant)
# layer1.1.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0270 calibrator=HistogramCalibrator quant)
# layer1.1.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1338 calibrator=HistogramCalibrator quant)
# layer1.1.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0287 calibrator=HistogramCalibrator quant)
# layer1.1.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1641 calibrator=HistogramCalibrator quant)
# layer1.1.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0338 calibrator=HistogramCalibrator quant)
# layer1.2.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2280 calibrator=HistogramCalibrator quant)
# layer1.2.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0412 calibrator=HistogramCalibrator quant)
# layer1.2.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1742 calibrator=HistogramCalibrator quant)
# layer1.2.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0334 calibrator=HistogramCalibrator quant)
# layer1.2.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.3181 calibrator=HistogramCalibrator quant)
# layer1.2.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0479 calibrator=HistogramCalibrator quant)
# layer2.0.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2314 calibrator=HistogramCalibrator quant)
# layer2.0.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0423 calibrator=HistogramCalibrator quant)
# layer2.0.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1688 calibrator=HistogramCalibrator quant)
# layer2.0.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0212 calibrator=HistogramCalibrator quant)
# layer2.0.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2021 calibrator=HistogramCalibrator quant)
# layer2.0.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0298 calibrator=HistogramCalibrator quant)
# layer2.0.downsample.0.quantizer         : TensorQuantizer(8bit per-tensor amax=0.2314 calibrator=HistogramCalibrator quant)
# layer2.0.downsample.0.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0273 calibrator=HistogramCalibrator quant)
# layer2.1.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1457 calibrator=HistogramCalibrator quant)
# layer2.1.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0200 calibrator=HistogramCalibrator quant)
# layer2.1.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1370 calibrator=HistogramCalibrator quant)
# layer2.1.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0167 calibrator=HistogramCalibrator quant)
# layer2.1.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1547 calibrator=HistogramCalibrator quant)
# layer2.1.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0267 calibrator=HistogramCalibrator quant)
# layer2.2.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1436 calibrator=HistogramCalibrator quant)
# layer2.2.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0243 calibrator=HistogramCalibrator quant)
# layer2.2.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1416 calibrator=HistogramCalibrator quant)
# layer2.2.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0189 calibrator=HistogramCalibrator quant)
# layer2.2.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1564 calibrator=HistogramCalibrator quant)
# layer2.2.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0303 calibrator=HistogramCalibrator quant)
# layer2.3.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1445 calibrator=HistogramCalibrator quant)
# layer2.3.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0273 calibrator=HistogramCalibrator quant)
# layer2.3.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1460 calibrator=HistogramCalibrator quant)
# layer2.3.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0215 calibrator=HistogramCalibrator quant)
# layer2.3.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1713 calibrator=HistogramCalibrator quant)
# layer2.3.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0277 calibrator=HistogramCalibrator quant)
# layer3.0.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1564 calibrator=HistogramCalibrator quant)
# layer3.0.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0266 calibrator=HistogramCalibrator quant)
# layer3.0.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1391 calibrator=HistogramCalibrator quant)
# layer3.0.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0128 calibrator=HistogramCalibrator quant)
# layer3.0.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1953 calibrator=HistogramCalibrator quant)
# layer3.0.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0160 calibrator=HistogramCalibrator quant)
# layer3.0.downsample.0.quantizer         : TensorQuantizer(8bit per-tensor amax=0.1564 calibrator=HistogramCalibrator quant)
# layer3.0.downsample.0.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0104 calibrator=HistogramCalibrator quant)
# layer3.1.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0989 calibrator=HistogramCalibrator quant)
# layer3.1.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0125 calibrator=HistogramCalibrator quant)
# layer3.1.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0928 calibrator=HistogramCalibrator quant)
# layer3.1.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0107 calibrator=HistogramCalibrator quant)
# layer3.1.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0925 calibrator=HistogramCalibrator quant)
# layer3.1.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0177 calibrator=HistogramCalibrator quant)
# layer3.2.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1070 calibrator=HistogramCalibrator quant)
# layer3.2.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0122 calibrator=HistogramCalibrator quant)
# layer3.2.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0835 calibrator=HistogramCalibrator quant)
# layer3.2.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0100 calibrator=HistogramCalibrator quant)
# layer3.2.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0869 calibrator=HistogramCalibrator quant)
# layer3.2.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0172 calibrator=HistogramCalibrator quant)
# layer3.3.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1203 calibrator=HistogramCalibrator quant)
# layer3.3.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0111 calibrator=HistogramCalibrator quant)
# layer3.3.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1005 calibrator=HistogramCalibrator quant)
# layer3.3.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0081 calibrator=HistogramCalibrator quant)
# layer3.3.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1283 calibrator=HistogramCalibrator quant)
# layer3.3.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0151 calibrator=HistogramCalibrator quant)
# layer3.4.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1385 calibrator=HistogramCalibrator quant)
# layer3.4.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0125 calibrator=HistogramCalibrator quant)
# layer3.4.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1092 calibrator=HistogramCalibrator quant)
# layer3.4.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0084 calibrator=HistogramCalibrator quant)
# layer3.4.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1342 calibrator=HistogramCalibrator quant)
# layer3.4.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0161 calibrator=HistogramCalibrator quant)
# layer3.5.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1916 calibrator=HistogramCalibrator quant)
# layer3.5.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0124 calibrator=HistogramCalibrator quant)
# layer3.5.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1145 calibrator=HistogramCalibrator quant)
# layer3.5.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0068 calibrator=HistogramCalibrator quant)
# layer3.5.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1466 calibrator=HistogramCalibrator quant)
# layer3.5.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0185 calibrator=HistogramCalibrator quant)
# layer4.0.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.4959 calibrator=HistogramCalibrator quant)
# layer4.0.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0093 calibrator=HistogramCalibrator quant)
# layer4.0.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.0823 calibrator=HistogramCalibrator quant)
# layer4.0.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0029 calibrator=HistogramCalibrator quant)
# layer4.0.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.2658 calibrator=HistogramCalibrator quant)
# layer4.0.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0087 calibrator=HistogramCalibrator quant)
# layer4.0.downsample.0.quantizer         : TensorQuantizer(8bit per-tensor amax=0.4959 calibrator=HistogramCalibrator quant)
# layer4.0.downsample.0.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0131 calibrator=HistogramCalibrator quant)
# layer4.1.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.5328 calibrator=HistogramCalibrator quant)
# layer4.1.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0029 calibrator=HistogramCalibrator quant)
# layer4.1.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1465 calibrator=HistogramCalibrator quant)
# layer4.1.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0040 calibrator=HistogramCalibrator quant)
# layer4.1.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.3072 calibrator=HistogramCalibrator quant)
# layer4.1.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0107 calibrator=HistogramCalibrator quant)
# layer4.2.conv1.quantizer                : TensorQuantizer(8bit per-tensor amax=0.8060 calibrator=HistogramCalibrator quant)
# layer4.2.conv1.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0024 calibrator=HistogramCalibrator quant)
# layer4.2.conv2.quantizer                : TensorQuantizer(8bit per-tensor amax=0.1307 calibrator=HistogramCalibrator quant)
# layer4.2.conv2.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0042 calibrator=HistogramCalibrator quant)
# layer4.2.conv3.quantizer                : TensorQuantizer(8bit per-tensor amax=0.3062 calibrator=HistogramCalibrator quant)
# layer4.2.conv3.quantizer_w              : TensorQuantizer(8bit per-tensor amax=0.0111 calibrator=HistogramCalibrator quant)

# %% [markdown]
# ## Run model evaluation
#
# Tip: observe how the execution becomes faster and faster with each batch as the CPU achieves better cache re-use on the LUT table

# %%
import timeit
correct = 0
total = 0

model.eval()
start_time = timeit.default_timer()
with torch.no_grad():
    for iteraction, (images, labels) in tqdm(enumerate(data), total=len(data)):
        images, labels = images.to("cpu"), labels.to("cpu")
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(timeit.default_timer() - start_time)
print('Accuracy of the network on the 10000 test images: %.4f %%' % (
    100 * correct / total))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [04:04<00:00,  3.13s/it]
# 244.47064731800128
# Accuracy of the network on the 10000 test images: 93.6098 %

# %% [markdown]
# ## Run approximate-aware re-training

# %%
from adapt.references.classification.train import evaluate, train_one_epoch, load_data

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)

# finetune the model for one epoch based on data_t subset 
train_one_epoch(model, criterion, optimizer, data_t, "cpu", 0, 1)
# Out:
# Epoch: [0]  [ 0/40]  eta: 0:14:01  lr: 0.0001  img/s: 6.0921665721491856  loss: 0.0850 (0.0850)  acc1: 98.4375 (98.4375)  acc5: 100.0000 (100.0000)  time:
  acc1: 99.2188 (99.2188)  acc5: 100.0000 (99.9740)  time: 20.1871  data: 0.0095  max mem: 0
# Epoch: [0]  [30/40]  eta: 0:03:23  lr: 0.0001  img/s: 6.485729359902353  loss: 0.0380 (0.0475)  acc1: 99.2188 (99.2440)  acc5: 100.0000 (99.9748)  time: 20.1480  data: 0.0095  max mem: 0
# Epoch: [0]  [31/40]  eta: 0:03:02  lr: 0.0001  img/s: 6.479710732165153  loss: 0.0396 (0.0491)  acc1: 99.2188 (99.1943)  acc5: 100.0000 (99.9756)  time: 20.1100  data: 0.0095  max mem: 0
# Epoch: [0]  [32/40]  eta: 0:02:42  lr: 0.0001  img/s: 6.468687812393311  loss: 0.0396 (0.0485)  acc1: 99.2188 (99.2188)  acc5: 100.0000 (99.9763)  time: 20.0729  data: 0.0095  max mem: 0
# Epoch: [0]  [33/40]  eta: 0:02:21  lr: 0.0001  img/s: 6.489583883201952  loss: 0.0396 (0.0487)  acc1: 99.2188 (99.1958)  acc5: 100.0000 (99.9770)  time: 20.0310  data: 0.0095  max mem: 0
# Epoch: [0]  [34/40]  eta: 0:02:01  lr: 0.0001  img/s: 6.451397561499156  loss: 0.0396 (0.0488)  acc1: 99.2188 (99.1964)  acc5: 100.0000 (99.9777)  time: 19.9984  data: 0.0095  max mem: 0
# Epoch: [0]  [35/40]  eta: 0:01:41  lr: 0.0001  img/s: 6.488328931649697  loss: 0.0396 (0.0483)  acc1: 99.2188 (99.2188)  acc5: 100.0000 (99.9783)  time: 19.9761  data: 0.0096  max mem: 0
# Epoch: [0]  [36/40]  eta: 0:01:20  lr: 0.0001  img/s: 6.308615261008745  loss: 0.0396 (0.0477)  acc1: 99.2188 (99.2399)  acc5: 100.0000 (99.9789)  time: 20.0075  data: 0.0095  max mem: 0
# Epoch: [0]  [37/40]  eta: 0:01:00  lr: 0.0001  img/s: 6.3026504920630435  loss: 0.0396 (0.0474)  acc1: 99.2188 (99.2393)  acc5: 100.0000 (99.9794)  time: 20.0367  data: 0.0095  max mem: 0
# Epoch: [0]  [38/40]  eta: 0:00:40  lr: 0.0001  img/s: 6.38321810142369  loss: 0.0396 (0.0472)  acc1: 99.2188 (99.2388)  acc5: 100.0000 (99.9800)  time: 20.0529  data: 0.0095  max mem: 0
# Epoch: [0]  [39/40]  eta: 0:00:19  lr: 0.0001  img/s: 7.0547445247801175  loss: 0.0478 (0.0560)  acc1: 99.2188 (99.2200)  acc5: 100.0000 (99.9800)  time: 19.1095  data: 0.0091  max mem: 0
# Epoch: [0] Total time: 0:13:10

# %% [markdown]
# ## Rerun model evaluation

# %%
correct = 0
total = 0

model.eval()
start_time = timeit.default_timer()
with torch.no_grad():
    for iteraction, (images, labels) in tqdm(enumerate(data), total=len(data)):
        images, labels = images.to("cpu"), labels.to("cpu")
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(timeit.default_timer() - start_time)
print('Accuracy of the network on the 10000 test images: %.4f %%' % (
    100 * correct / total))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [03:56<00:00,  3.03s/it]
# 236.517016703001
# Accuracy of the network on the 10000 test images: 93.4095 %
